# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("https://gist.githubusercontent.com/miguelpinia/3d589ad7c4365d2686a79bb7962bba04/raw/5fd04ffe66ef3c762deb81fe689b0730ea84e603/brain_size.csv",delimiter=';')
df.head()
# Out:
#    Unnamed: 0  Gender  FSIQ  VIQ  PIQ Weight Height  MRI_Count
# 0           1  Female   133  132  124    118   64.5     816932
# 1           2    Male   140  150  124      .   72.5    1001121
# 2           3    Male   139  123  150    143   73.3    1038437
# 3           4    Male   133  129  128    172   68.8     965353
# 4           5  Female   137  132  134    147   65.0     951545

# %%
df=df.rename(columns={"Unnamed: 0":"Id"})
df.head(40)
# Out:
#     Id  Gender  FSIQ  VIQ  PIQ Weight Height  MRI_Count
# 0    1  Female   133  132  124    118   64.5     816932
# 1    2    Male   140  150  124      .   72.5    1001121
# 2    3    Male   139  123  150    143   73.3    1038437
# 3    4    Male   133  129  128    172   68.8     965353
# 4    5  Female   137  132  134    147   65.0     951545
# 5    6  Female    99   90  110    146   69.0     928799
# 6    7  Female   138  136  131    138   64.5     991305
# 7    8  Female    92   90   98    175   66.0     854258
# 8    9    Male    89   93   84    134   66.3     904858
# 9   10    Male   133  114  147    172   68.8     955466
# 10  11  Female   132  129  124    118   64.5     833868
# 11  12    Male   141  150  128    151   70.0    1079549
# 12  13    Male   135  129  124    155   69.0     924059
# 13  14  Female   140  120  147    155   70.5     856472
# 14  15  Female    96  100   90    146   66.0     878897
# 15  16  Female    83   71   96    135   68.0     865363
# ...

# %%
#check the columns
df.columns
# Out:
# Index(['Id', 'Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height', 'MRI_Count'], dtype='object')

# %%
#check the datatypes of  culumns
df.dtypes
# Out:
# Id            int64
# Gender       object
# FSIQ          int64
# VIQ           int64
# PIQ           int64
# Weight       object
# Height       object
# MRI_Count     int64
# dtype: object

# %%
# df["Weight"] = [float(i) if isinstance(i, (int, float)) else np.nan for i in df.Weight]
# df["Height"] = [float(i) if isinstance(i, (int, float)) else np.nan for i in df.Weight]

# %%
df['Weight'] = pd.to_numeric(df['Weight'], errors='coerce')
df["Height"]= pd.to_numeric(df['Height'], errors='coerce')

# %%
df.head(40)
# Out:
#     Id  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0    1  Female   133  132  124   118.0    64.5     816932
# 1    2    Male   140  150  124     NaN    72.5    1001121
# 2    3    Male   139  123  150   143.0    73.3    1038437
# 3    4    Male   133  129  128   172.0    68.8     965353
# 4    5  Female   137  132  134   147.0    65.0     951545
# 5    6  Female    99   90  110   146.0    69.0     928799
# 6    7  Female   138  136  131   138.0    64.5     991305
# 7    8  Female    92   90   98   175.0    66.0     854258
# 8    9    Male    89   93   84   134.0    66.3     904858
# 9   10    Male   133  114  147   172.0    68.8     955466
# 10  11  Female   132  129  124   118.0    64.5     833868
# 11  12    Male   141  150  128   151.0    70.0    1079549
# 12  13    Male   135  129  124   155.0    69.0     924059
# 13  14  Female   140  120  147   155.0    70.5     856472
# 14  15  Female    96  100   90   146.0    66.0     878897
# ...

# %%
df.dtypes
# Out:
# Id             int64
# Gender        object
# FSIQ           int64
# VIQ            int64
# PIQ            int64
# Weight       float64
# Height       float64
# MRI_Count      int64
# dtype: object

# %%
df.head()
# Out:
#    Id  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0   1  Female   133  132  124   118.0    64.5     816932
# 1   2    Male   140  150  124     NaN    72.5    1001121
# 2   3    Male   139  123  150   143.0    73.3    1038437
# 3   4    Male   133  129  128   172.0    68.8     965353
# 4   5  Female   137  132  134   147.0    65.0     951545

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         40 non-null     int64
#  1   Gender     40 non-null     object
#  2   FSIQ       40 non-null     int64
#  3   VIQ        40 non-null     int64
#  4   PIQ        40 non-null     int64
#  5   Weight     38 non-null     float64
#  6   Height     39 non-null     float64
#  7   MRI_Count  40 non-null     int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 2.6+ KB

# %%
df.head()
# Out:
#    Id  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0   1  Female   133  132  124   118.0    64.5     816932
# 1   2    Male   140  150  124     NaN    72.5    1001121
# 2   3    Male   139  123  150   143.0    73.3    1038437
# 3   4    Male   133  129  128   172.0    68.8     965353
# 4   5  Female   137  132  134   147.0    65.0     951545

# %%
#check the shape of data
df.shape
# Out:
# (40, 8)

# %%
df.isnull().sum()
# Out:
# Id           0
# Gender       0
# FSIQ         0
# VIQ          0
# PIQ          0
# Weight       2
# Height       1
# MRI_Count    0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# True

# %%
#check null value using heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# Observaiton:-some of null value present in Weight and HEight data

# %%
df["Weight"]=df["Weight"].fillna(df["Weight"].mean())
df["Height"]=df["Height"].fillna(df["Height"].mean())

# %%
#check null value using heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# No null value in data

# %%
df.isnull().values.any()
# Out:
# False

# %%
#statistical analysis 
df.describe()
# Out:
#               Id        FSIQ         VIQ        PIQ      Weight     Height  \
# count  40.000000   40.000000   40.000000   40.00000   40.000000  40.000000
# mean   20.500000  113.450000  112.350000  111.02500  151.052632  68.525641
# std    11.690452   24.082071   23.616107   22.47105   22.868574   3.943103
# min     1.000000   77.000000   71.000000   72.00000  106.000000  62.000000
# 25%    10.750000   89.750000   90.000000   88.25000  135.750000  66.000000
# 50%    20.500000  116.500000  113.000000  115.00000  147.500000  68.250000
# 75%    30.250000  135.500000  129.750000  128.00000  172.000000  70.500000
# max    40.000000  144.000000  150.000000  150.00000  192.000000  77.000000
#
#           MRI_Count
# count  4.000000e+01
# mean   9.087550e+05
# std    7.228205e+04
# min    7.906190e+05
# 25%    8.559185e+05
# 50%    9.053990e+05
# 75%    9.500780e+05
# max    1.079549e+06

# %% [markdown]
# Observation:- We can find all statistcal calulation like mean,std,min,max,percentile form above

# %% [markdown]
# # correlation of data

# %%
df.corr()
# Out:
#                  Id      FSIQ       VIQ       PIQ    Weight    Height  \
# Id         1.000000 -0.334072 -0.241473 -0.371150  0.168519  0.123772
# FSIQ      -0.334072  1.000000  0.946639  0.934125 -0.049590 -0.084175
# VIQ       -0.241473  0.946639  1.000000  0.778135 -0.071988 -0.069610
# PIQ       -0.371150  0.934125  0.778135  1.000000  0.002461 -0.075462
# Weight     0.168519 -0.049590 -0.071988  0.002461  1.000000  0.690199
# Height     0.123772 -0.084175 -0.069610 -0.075462  0.690199  1.000000
# MRI_Count -0.139724  0.357641  0.337478  0.386817  0.501977  0.601308
#
#            MRI_Count
# Id         -0.139724
# FSIQ        0.357641
# VIQ         0.337478
# PIQ         0.386817
# Weight      0.501977
# Height      0.601308
# MRI_Count   1.000000

# %%
#we can observe corr by heat map
sns.heatmap(df.corr(),annot=True,fmt='.2%',cmap="ocean")
# Out:
# <AxesSubplot: >

# %% [markdown]
# Observation:- In above plot we can see VIQ-FSIQ-PIQ are highly correlated

# %% [markdown]
# # Univariate analysis

# %%
df.columns
# Out:
# Index(['Id', 'Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height', 'MRI_Count'], dtype='object')

# %%
#plot bar plot of 
import plotly.express as px
plot=px.bar(df,x="Gender",color="Gender")
plot.show()

# %% [markdown]
# we can observe that the no.of Male and Female Gender are same 20-20

# %%
#countplot for FSIQ
plt.figure(figsize=(10,5))
sns.countplot(df,x="FSIQ")
# Out:
# <AxesSubplot: xlabel='FSIQ', ylabel='count'>

# %% [markdown]
# From above we can observe that maximum 5 people have FSIQ 133 and avg people have more than 100

# %%
#countplot for VIQ
plt.figure(figsize=(10,5))
sns.countplot(df,x="VIQ",palette="Set1")
# Out:
# <AxesSubplot: xlabel='VIQ', ylabel='count'>

# %% [markdown]
# from above we observe max people have VIQ between 83-96 and 126-150. almost 32 people of that VIQ

# %%
#plot histogram using plotly
histplot=px.histogram(df,x="PIQ",color="PIQ")
histplot.show()

# %% [markdown]
# From above plot observe that most of people have there PIQ between 80 t0 100 and 120 t0 140

# %% [markdown]
# Also we can find every PIQ from color bar

# %%
#count plot for Weight
plt.figure(figsize=(15,6))
sns.countplot(df,x="Weight",palette="Set3")
# Out:
# <AxesSubplot: xlabel='Weight', ylabel='count'>

# %% [markdown]
# From above plot we can observe most of people have different weight

# %%
#histogram of Height using plotly
plot=px.histogram(df,x="Height",color="Height")
plot.show()

# %% [markdown]
# Observation:-max 4 people have same height of 64.5 and 3 of 69,68,66.5 .And we can find all height by the color bar and cross bar over the plot

# %%
#countpolt of MRI_Count
plt.figure(figsize=(15,6))
sns.countplot(df,x="MRI_Count")
# Out:
# <AxesSubplot: xlabel='MRI_Count', ylabel='count'>

# %% [markdown]
# Observation:- Everybody have their different MRI_Count

# %% [markdown]
# # Bivariate analysis

# %%
#target table is MRI_Count

# %%
df.columns
# Out:
# Index(['Id', 'Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height', 'MRI_Count'], dtype='object')

# %% [markdown]
# # Gender vs MRI_Count

# %%
#histogram plot between Gender and MRI_Count
px.histogram(df,x="Gender",y="MRI_Count",color="MRI_Count")

# %% [markdown]
# Observation :- Here observed that male has more MRI_Count more than Female
#     ,u can find all MRI_Count by cross bar over plot and color bar

# %% [markdown]
# # FSIQ vs MRI_Count

# %%
#barplot using plotly
px.bar(df,x="FSIQ",y="MRI_Count",color="MRI_Count")

# %% [markdown]
# Observation :- Most(Avg) of the FSIQ is from 0 to 1M MRI_Count range

# %% [markdown]
# # VIQ vs MRI_Count

# %%
#plot scatter plot usong seaborn
sns.scatterplot(df,x="VIQ",y="MRI_Count")
# Out:
# <AxesSubplot: xlabel='VIQ', ylabel='MRI_Count'>

# %% [markdown]
# Observation :- Avg VIQ is from 0.80 to 1.00 of MRI_Count range

# %% [markdown]
# # Weight vs MRI_Count

# %%
# histogram using plotly
px.histogram(df,x="Weight",y="MRI_Count",color="MRI_Count")

# %% [markdown]
# Observation :- Here w can see the avg Weight is from the range of 0 to 1 of MRI_Count range

# %% [markdown]
# # Height vs MRI_Count

# %%
# plot scatter plot using plotly
px.scatter(df,x="Height",y="MRI_Count",color="MRI_Count")

# %% [markdown]
# Observation :- From above plot we can see the avg HEight is from 0 to 1 range of MRI_Count range and all height and MRI_Countcan find by cross bar over the plot

# %%
#plot violin plot of HEight
plt.figure(figsize=(15,6))
sns.violinplot(df,x="Height",y="MRI_Count")
# Out:
# <AxesSubplot: xlabel='Height', ylabel='MRI_Count'>

# %% [markdown]
# # Multivariate analysis

# %% [markdown]
# # Gender vs FSIQ vs MRI_Count

# %%
#scatter plot 
px.scatter_3d(df,x="Gender",y="FSIQ",z="MRI_Count",color="Gender")

# %%
#line_3d plot usng lplotly
px.line_3d(df,x="Gender",y="FSIQ",z="MRI_Count")

# %% [markdown]
# Observation:- Most of people between 0.8M t0 0.95M MRI_Count range and 80 t0 100 FSIQ range u can see 3 atributes over the plot by cross bar

# %% [markdown]
# #  PIQ vs FSIQ vs MRI_Count

# %%
#scattet 3d plot
px.scatter_3d(df,x="PIQ",y="FSIQ",z="MRI_Count",color="PIQ",)

# %% [markdown]
# Observation :- Most of people are from 70 to 120 FSIQ range,70 to 100 PIQ range,0.8M to 0.95M MRI_Count range

# %% [markdown]
# # Height vs Weight vs MRI_Count

# %%
#bar plot 
plt.figure(figsize=(15,8),facecolor="yellow")
sns.stripplot(df,x="Height",y="Weight",hue="MRI_Count")
# Out:
# <AxesSubplot: xlabel='Height', ylabel='Weight'>

# %% [markdown]
# Observation :- we can see here weight and Height are negatively correlated and MRI_Count can observe by color bar

# %%
#pair plot 
plt.figure(figsize=(12,5))
sns.pairplot(df,hue="MRI_Count")
plt.show()

# %% [markdown]
# # Outliers

# %%
#box plot for checking outliers
for i in df.columns:
    if df[i].dtypes!="object":
        plt.figure(figsize=(3,2))
        sns.boxplot(df[i])
        plt.xlabel(f"{i}")
        plt.show()

# %% [markdown]
# Observation : - There is no outliers in data

# %% [markdown]
# # Skewness

# %%
#box plot for checking outliers
for i in df.columns:
    if df[i].dtypes!="object":
        plt.figure(figsize=(3,2))
        sns.kdeplot(df[i],color="pink")
       
        plt.show()

# %% [markdown]
# NO skewed data

# %%
df.skew()
# Out:
# Id           0.000000
# FSIQ        -0.124854
# VIQ          0.073754
# PIQ         -0.101205
# Weight       0.138463
# Height       0.482052
# MRI_Count    0.370250
# dtype: float64

# %%
#label encoder
from sklearn.preprocessing import LabelEncoder

for i in df.columns:
    if df[i].dtypes=="O":
        print(i)
        df[i]=LabelEncoder.fit_transform(df,df[i])
# Out:
# Gender

# %%
#normalisation of data
y=df[['MRI_Count']]
df_test=df.drop(columns="MRI_Count")
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
df_test_m=m.fit_transform(df_test)

# %%
x=pd.DataFrame(data=df_test_m,columns=df_test.columns)

# %%
x.shape
# Out:
# (40, 7)

# %%
y.shape
# Out:
# (40, 1)

# %%
from screeplot import scree as sp
sp.scree_plot(x)

# %% [markdown]
# # Basic imports for model teaining

# %%
#Bsic imports for model teaining
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import OneHotEncoder,PowerTransformer, StandardScaler, MinMaxScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split,RandomizedSearchCV, GridSearchCV
import pickle

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.shape
# Out:
# (28, 7)

# %%
x_test.shape
# Out:
# (12, 7)

# %%
lr=LinearRegression()

# %%
    
model=lr
model.fit(x_train,y_train)
pre=model.predict(x_test)
r2=r2_score(y_test,pre)
print('R2_score = ',r2)

mse=mean_squared_error(y_test,pre)
print("Mean_Squared_Error =",mse)

b=np.sqrt(mse)
print('RMSE= ',b)

score= cross_val_score(model,x,y,cv=10,scoring='r2').mean()
print('Cross_Val_Score = ',score)

print('\n')
# Out:
# R2_score =  0.2753188100076257
# Mean_Squared_Error = 3144199965.5208316
# RMSE=  56073.16618063253
# Cross_Val_Score =  -0.15390427287903422

# %% [markdown]
# # Ridge regression

# %%
from sklearn.linear_model import  Ridge
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

Rd=Ridge()
Rd.fit(x_train,y_train)
#make prediction
y_train_pred=Rd.predict(x_train)
y_test_pred=Rd.predict(x_test)

#train set performance
train_r2_score=r2_score(y_train,y_train_pred)
model_train_mae=mean_absolute_error(y_train,y_train_pred)
model_train_mse=mean_squared_error(y_train,y_train_pred)
model_train_RMSE=np.sqrt(model_train_mse)

#test set performance
test_r2_score=r2_score(y_test,y_test_pred)
model_test_mae= mean_absolute_error(y_test,y_test_pred)
model_test_mse=mean_squared_error(y_test,y_test_pred)
model_test_RMSE=np.sqrt(model_test_mse)

#train set performance
print("Model train set performance : ")
print("R2 score :{:.4f}".format(train_r2_score))
print("MAE:{:.4f}".format(model_train_mae))
print("MSE :{:.4f}".format(model_train_mse))
print("RMSE :{:.4f}".format(model_train_RMSE))

#test set performance
print(15*"-")
print("Model test set performance : ")
print("R2 score :{:.4f}".format(test_r2_score))
print("MAE:{:.4f}".format(model_test_mae))
print("MSE :{:.4f}".format(model_test_mse))
print("RMSE :{:.4f}".format(model_test_RMSE))

score= cross_val_score(Rd,x,y,cv=10,scoring='r2').mean()
print("cross_val_score : ",score)
# Out:
# Model train set performance :
# R2 score :0.7051
# MAE:29227.9093
# MSE :1569176543.3911
# RMSE :39612.8331
# ---------------
# Model test set performance :
# R2 score :0.2682
# MAE:47337.7206
# MSE :3174962587.6159
# RMSE :56346.8064
# cross_val_score :  -0.2243041528979953

# %% [markdown]
# # Lasso regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score, mean_absolute_error
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
ls=Lasso()
ls.fit(x_train,y_train)

#make prediction
y_train_pred=ls.predict(x_train)
y_test_pred=ls.predict(x_test)

#model train set performance
train_r2_score=r2_score(y_train,y_train_pred)
model_tran_mae=mean_absolute_error(y_train,y_train_pred)
model_train_mse=mean_squared_error(y_train,y_train_pred)
model_train_RMSE=np.sqrt(model_train_mse)

#model test set performance
test_r2_score=r2_score(y_test,y_test_pred)
model_test_mae=mean_absolute_error(y_test,y_test_pred)
model_test_mse=mean_squared_error(y_test,y_test_pred)
model_test_RMSE=np.sqrt(model_test_mse)

print("Model train set performance")
print("R2_score :{:.4f}".format(train_r2_score))
print("Mean_absolute_error :{:.4f}".format(model_train_mae))
print("MSE :{:.4f}".format(model_train_mse))
print("RMSE :{:.4f}".format(model_train_RMSE))

print(20*"*")

print("Model test set performance")
print("R2_score :{:.4f}".format(test_r2_score))
print("MAE :{:.4f}".format(model_test_mae))
print("MSE :{:.4f}".format(model_test_mse))
print("RMSE :{:.4f}".format(model_test_RMSE))

score= cross_val_score(ls,x,y,cv=10,scoring='r2').mean()
print("cross_val_score : ",score)
# Out:
# Model train set performance
# R2_score :0.7913
# Mean_absolute_error :29227.9093
# MSE :1110413369.0975
# RMSE :33322.8656
# ********************
# Model test set performance
# R2_score :0.2772
# MAE :47465.8554
# MSE :3135891139.7540
# RMSE :55999.0280
# cross_val_score :  -0.15685766946616891

# %% [markdown]
# # Support vecor regression

# %%
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_absolute_error
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
sr=SVR()
sr.fit(x_train,y_train)
#make prediction
y_train_pred=sr.predict(x_train)
y_test_pred=sr.predict(x_test)

#model train set performance
train_r2_score=r2_score(y_train,y_train_pred)
model_tran_mae=mean_absolute_error(y_train,y_train_pred)
model_train_mse=mean_squared_error(y_train,y_train_pred)
model_train_RMSE=np.sqrt(model_train_mse)

#model test set performance
test_r2_score=r2_score(y_test,y_test_pred)
model_test_mae=mean_absolute_error(y_test,y_test_pred)
model_test_mse=mean_squared_error(y_test,y_test_pred)
model_test_RMSE=np.sqrt(model_test_mse)

print("Model train set performance")
print("R2_score :{:.4f}".format(train_r2_score))
print("Mean_absolute_error :{:.4f}".format(model_train_mae))
print("MSE :{:.4f}".format(model_train_mse))
print("RMSE :{:.4f}".format(model_train_RMSE))

print(20*"*")

print("Model test set performance")
print("R2_score :{:.4f}".format(test_r2_score))
print("MAE :{:.4f}".format(model_test_mae))
print("MSE :{:.4f}".format(model_test_mse))
print("RMSE :{:.4f}".format(model_test_RMSE))

score= cross_val_score(sr,x,y,cv=10,scoring='r2').mean()
print("cross_val_score : ",score)
# Out:
# Model train set performance
# R2_score :-0.0042
# Mean_absolute_error :29227.9093
# MSE :5343686596.9876
# RMSE :73100.5239
# ********************
# Model test set performance
# R2_score :-0.1182
# MAE :54967.1933
# MSE :4851610866.0217
# RMSE :69653.5058
# cross_val_score :  -0.6666378850731074

# %% [markdown]
# # KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score, mean_absolute_error
nr=KNeighborsRegressor()
nr.fit(x_train,y_train)

# make prediction
y_train_pred=nr.predict(x_train)
y_test_pred=nr.predict(x_test)

#model train set performance
train_r2_score=r2_score(y_train,y_train_pred)
model_train_mae=mean_absolute_error(y_train,y_train_pred)
model_train_mse=mean_squared_error(y_train,y_train_pred)
model_train_RMSE=np.sqrt(model_train_mse)

#model test set performance
test_r2_score=r2_score(y_test,y_test_pred)
model_test_mae=mean_absolute_error(y_test,y_test_pred)
model_test_mse=mean_squared_error(y_test,y_test_pred)
model_test_RMSE=np.sqrt(model_test_mse)

print("Model train set performance :")
print("R2_score :{:.4f}".format(train_r2_score))
print("MAE :{:.4f}".format(model_train_mae))
print("MSE :{:.4f}".format(model_train_mse))
print("RMSE :{:.4f}".format(model_train_RMSE))

print(20*"^")
print("model test set perfomance :")
print("R2_score :{:.4f}".format(test_r2_score))
print("MAE :{:.4f}".format(model_test_mae))
print("MSE :{:.4f}".format(model_test_mse))
print("RMSE :{:.4f}".format(model_test_RMSE))

score= cross_val_score(nr,x,y,cv=10,scoring='r2').mean()
print("cross_val_score : ",score)
# Out:
# Model train set performance :
# R2_score :0.7278
# MAE :28954.8071
# MSE :1448324783.6357
# RMSE :38056.8625
# ^^^^^^^^^^^^^^^^^^^^
# model test set perfomance :
# R2_score :-0.4277
# MAE :60468.5333
# MSE :6194242871.1000
# RMSE :78703.5124
# cross_val_score :  -0.5041341249503954

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_absolute_error
dt=DecisionTreeRegressor()
#fit the train data
dt.fit(x_train,y_train)

#make prediction
y_tain_pred=dt.predict(x_train)
y_test_pred=dt.predict(x_test)

#model train set performance
train_r2_score=r2_score(y_train,y_train_pred)
model_train_mae=mean_absolute_error(y_train,y_train_pred)
model_train_mse=mean_squared_error(y_train,y_train_pred)
model_train_RMSE=np.sqrt(model_train_mse)

#model test set performance
test_r2_score=r2_score(y_test,y_test_pred)
model_test_mae=mean_absolute_error(y_test,y_test_pred)
model_test_mse=mean_squared_error(y_test,y_test_pred)
model_test_RMSE=np.sqrt(model_test_mse)

print("Model train set performance")
print("R2 score :{:.4f}".format(train_r2_score))
print("MAE :{:.4f}".format(model_train_mae))
print("MSE :{:.4f}".format(model_train_mse))
print("RMSE :{:.4f}".format(model_train_RMSE))

print(20*"*")

print("model test set performance")
print("R2_score :{:.4f}".format(test_r2_score))
print("MAE :{:.4f}".format(model_test_mae))
print("MSE :{:.4f}".format(model_test_mse))
print("RMSE :{:.4f}".format(model_test_RMSE))

score= cross_val_score(dt,x,y,cv=10,scoring='r2').mean()
print("cross_val_score : ",score)
# Out:
# Model train set performance
# R2 score :0.7278
# MAE :28954.8071
# MSE :1448324783.6357
# RMSE :38056.8625
# ********************
# model test set performance
# R2_score :-0.0959
# MAE :44896.5833
# MSE :4754820964.5833
# RMSE :68955.2098
# cross_val_score :  -1.5692824381111528

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error
#fit the train data
rf=RandomForestRegressor()
rf.fit(x_train,y_train)

#make prediction
y_train_pred=rf.predict(x_train)
y_test_pred=rf.predict(x_test)

#model train set performance
train_r2_score=r2_score(y_train,y_train_pred)
model_train_mae=mean_absolute_error(y_train,y_train_pred)
model_train_mse=mean_squared_error(y_train,y_train_pred)
model_train_RMSE=np.sqrt(model_train_mse)

#model train set performance
test_r2_score=r2_score(y_test,y_test_pred)
model_test_mae=mean_absolute_error(y_test,y_test_pred)
model_test_mse=mean_squared_error(y_test,y_test_pred)
model_test_RMSE=np.sqrt(model_test_mse)

print("model train set performance :")
print("R2_score :{:.4f}".format(train_r2_score))
print("MAE :{:.4f}".format(model_train_mae))
print("MSE :{:.4f}".format(model_train_mse))
print("RMSE :{:.4f}".format(model_train_RMSE))

print(20*"-")

print("Model test set performance :")
print("R2_score :{:.4f}".format(test_r2_score))
print("MAE : {:.4f}".format(model_test_mae))
print("MSE :{:.4f}".format(model_test_mse))
print("RMSE :{:.4f}".format(model_test_RMSE))

score= cross_val_score(rf,x,y,cv=10,scoring='r2').mean()
print("cross_val_score : ",score)
# Out:
# model train set performance :
# R2_score :0.9323
# MAE :15104.6643
# MSE :360062232.8280
# RMSE :18975.3059
# --------------------
# Model test set performance :
# R2_score :0.0508
# MAE : 48696.3192
# MSE :4118335028.4613
# RMSE :64174.2552
# cross_val_score :  -0.37192344346743805

# %%
from sklearn.pipeline import Pipeline
#create a pipeline with logistic regression 
model=Pipeline(steps=[('min_max_scaler',MinMaxScaler()),('Linear regerssion', LinearRegression())])

# %%
model
# Out:
# Pipeline(steps=[('min_max_scaler', MinMaxScaler()),
#                 ('Linear regerssion', LinearRegression())])

# %%
final_model=model.fit(x_train,y_train)

# %%
final_model.predict(x_test)
# Out:
# array([[ 909322.74494609],
#        [ 861780.52663929],
#        [ 840734.65979465],
#        [ 861643.88399473],
#        [ 885669.6372892 ],
#        [ 883456.96799644],
#        [ 835339.06067671],
#        [ 994232.55980741],
#        [ 955517.97607351],
#        [ 874452.97525035],
#        [1000210.19740722],
#        [ 973874.60957244]])

# %%
x_test.shape
# Out:
# (12, 7)

# %%
import joblib
model=joblib.dump(final_model,"bsize.pkl")

# %%
x_test
# Out:
#           Id  Gender      FSIQ       VIQ       PIQ    Weight    Height
# 19  0.487179     1.0  0.044776  0.075949  0.179487  0.860465  0.533333
# 16  0.410256     0.0  0.820896  0.772152  0.615385  0.244186  0.433333
# 15  0.384615     0.0  0.089552  0.000000  0.307692  0.337209  0.400000
# 26  0.666667     0.0  0.119403  0.240506  0.153846  0.395349  0.400000
# 4   0.102564     0.0  0.895522  0.772152  0.794872  0.476744  0.200000
# 12  0.307692     1.0  0.865672  0.734177  0.666667  0.569767  0.466667
# 37  0.948718     0.0  0.164179  0.189873  0.282051  0.383721  0.166667
# 27  0.692308     1.0  0.388060  0.316456  0.487179  0.941860  1.000000
# 39  1.000000     1.0  0.179104  0.253165  0.217949  0.848837  0.900000
# 6   0.153846     0.0  0.910448  0.822785  0.756410  0.372093  0.166667
# 25  0.641026     1.0  0.955224  0.936709  0.756410  0.755814  0.666667
# 9   0.230769     1.0  0.835821  0.544304  0.961538  0.767442  0.453333
